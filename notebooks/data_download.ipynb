# %%
import os
from huggingface_hub import snapshot_download

# Set HF_DATASET_REPO to wherever your raw MOT tracking data is hosted.
zip_path = snapshot_download(
    repo_id=os.environ["HF_DATASET_REPO"],
    repo_type="dataset",
    local_dir="../raw_data",
    token=os.getenv("HF_TOKEN"),
)
print(zip_path)
